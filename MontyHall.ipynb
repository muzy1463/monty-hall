# %% [markdown]
# # Monty Hall Problem

# %% [markdown]
# Monty Hall Problem is one of the most popular problems in statistics.

# %% [markdown]
# Here is the story, told by Marilyn vos Savant, in her column "Ask Marilyn" in Parade magazine:

# %% [markdown]
# Suppose you're on a game show, and you're given the choice of three doors:
# - Behind one door is a car
# - Behind the others, goats.
#
# You pick a door, say No. 1, and the host, who knows what's behind the doors, opens another door, say No. 3, which has a goat.
#
# He then says to you, "Do you want to pick door No. 2?" Is it to your advantage to switch your choice?

# %% [markdown]
# ![1200px-Monty_open_door.svg-2.png](attachment:1200px-Monty_open_door.svg-2.png)

# %% [markdown]
# Although it seems like the odds are 50% now, instead of 33.3%, it is surprisingly not.

# %% [markdown]
# <strong>Switching is always the best strategy.</strong>

# %% [markdown]
# Want to know why? Let's explore below!

# %% [markdown]
# ## Import the random library

# %%
import random

# %% [markdown]
# ## Set up a trial function for Monty Hall

# %%
def monty_simulation(switch=True, number_of_doors=3):
    """Runs a Monty Simulation for once. If the switch is true, the player switches his/her door at the end. 
    Else, the player sticks to his/her choice.
    0 represents a goat, and 1 represents the car. 
    """
    
    # Build a list full of goats, and only one car.
    doors = [0 for i in range(0, number_of_doors - 1)]
    doors.append(1)
    
    # Shuffle the list
    random.shuffle(doors)
    door_with_car = doors.index(1)
    
    # The player chooses randomly
    chosen_value = doors[random.randint(0, number_of_doors - 1)]

    # If the player chose the door with car, switch option is goat, else car.
    if door_with_car == chosen_value:
        not_chosen = 0 # goat
    else:
        not_chosen = 1 # car

    if switch: 
        chosen_value = not_chosen

    return chosen_value

# %%
def calculate_probability(number_of_doors:int, number_of_trials:int):
    """A function to calculate the experimental probability of winning the car by switching and not switching, 
    for number_of_doors, for the number of trials.
    """
    
    assert number_of_doors > 2, "The number of doors should be more than 2."
    switching_probability = 0
    non_switching_probability = 0

    for i in range(0, number_of_trials):
        switching_probability += monty_simulation(True, number_of_doors)
        non_switching_probability += monty_simulation(False, number_of_doors)


    non_switching_probability = non_switching_probability / number_of_trials
    switching_probability = switching_probability / number_of_trials

    print("*"*100)
    print("Number of doors: ", number_of_doors)
    print("Number of trials: ", number_of_trials)
    print(f"If the user does switch, s/he has a probability of {switching_probability} winning the car")
    print(f"If the user does not switch, s/he has a probability of {non_switching_probability} winning the car")
    print("*"*100)

# %% [markdown]
# ## Calculate for 3 doors, with 10.000 trials

# %%
calculate_probability(number_of_doors=3, number_of_trials=10000)
# Out:
# ****************************************************************************************************
# Number of doors:  3
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.6644 winning the car
# If the user does not switch, s/he has a probability of 0.3377 winning the car
# ****************************************************************************************************

# %% [markdown]
# <strong>As you see, the probability of winning the car is way higher if you switch!</strong>

# %% [markdown]
# Why though? Let's try to understand it intuitively.

# %% [markdown]
# Assume the number of doors is 1000.
# Now,
# - The probability of you choosing the door with car is 0.001
# - The probability of the car being in the not chosen doors is 0.999

# %% [markdown]
# Hence, the car is in the doors you did not choose, with the probability of 0.999

# %% [markdown]
# <strong>If you switch in the end, you actually open 999 boxes. <br><br>
# If not, only 1.
#
# Most likely, the car will be in one of the 999 doors, not in the door you randomly chose out of 1000.</strong>

# %% [markdown]
# Moreover, as the number of doors increase, the probability of picking the door with car increases if you choose to switch. Let's verify below.

# %%
for i in range(3, 101):
    calculate_probability(number_of_doors = i, number_of_trials = 10000)
# Out:
# ****************************************************************************************************
# Number of doors:  3
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.6587 winning the car
# If the user does not switch, s/he has a probability of 0.3427 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  4
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.7543 winning the car
# If the user does not switch, s/he has a probability of 0.2582 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  5
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.7978 winning the car
# If the user does not switch, s/he has a probability of 0.194 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  6
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.8321 winning the car
# If the user does not switch, s/he has a probability of 0.1685 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  7
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.8587 winning the car
# If the user does not switch, s/he has a probability of 0.1511 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  8
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.8778 winning the car
# If the user does not switch, s/he has a probability of 0.1265 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  9
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.8934 winning the car
# If the user does not switch, s/he has a probability of 0.1126 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  10
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9041 winning the car
# If the user does not switch, s/he has a probability of 0.098 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  11
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9096 winning the car
# If the user does not switch, s/he has a probability of 0.0907 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  12
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9128 winning the car
# If the user does not switch, s/he has a probability of 0.081 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  13
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9262 winning the car
# If the user does not switch, s/he has a probability of 0.0764 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  14
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.931 winning the car
# If the user does not switch, s/he has a probability of 0.0705 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  15
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9331 winning the car
# If the user does not switch, s/he has a probability of 0.0673 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  16
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9387 winning the car
# If the user does not switch, s/he has a probability of 0.0596 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  17
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9432 winning the car
# If the user does not switch, s/he has a probability of 0.0589 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  18
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9424 winning the car
# If the user does not switch, s/he has a probability of 0.0555 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  19
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9445 winning the car
# If the user does not switch, s/he has a probability of 0.0511 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  20
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9494 winning the car
# If the user does not switch, s/he has a probability of 0.0485 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  21
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9482 winning the car
# If the user does not switch, s/he has a probability of 0.0534 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  22
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9529 winning the car
# If the user does not switch, s/he has a probability of 0.0468 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  23
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9598 winning the car
# If the user does not switch, s/he has a probability of 0.044 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  24
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9601 winning the car
# If the user does not switch, s/he has a probability of 0.0407 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  25
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9613 winning the car
# If the user does not switch, s/he has a probability of 0.0407 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  26
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9628 winning the car
# If the user does not switch, s/he has a probability of 0.0416 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  27
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9634 winning the car
# If the user does not switch, s/he has a probability of 0.0354 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  28
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9616 winning the car
# If the user does not switch, s/he has a probability of 0.0329 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  29
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9659 winning the car
# If the user does not switch, s/he has a probability of 0.0365 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  30
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9685 winning the car
# If the user does not switch, s/he has a probability of 0.0313 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  31
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9648 winning the car
# If the user does not switch, s/he has a probability of 0.0326 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  32
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9703 winning the car
# If the user does not switch, s/he has a probability of 0.0311 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  33
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9715 winning the car
# If the user does not switch, s/he has a probability of 0.0287 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  34
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9711 winning the car
# If the user does not switch, s/he has a probability of 0.0294 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  35
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.971 winning the car
# If the user does not switch, s/he has a probability of 0.0277 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  36
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9736 winning the car
# If the user does not switch, s/he has a probability of 0.0245 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  37
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9748 winning the car
# If the user does not switch, s/he has a probability of 0.0254 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  38
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9743 winning the car
# If the user does not switch, s/he has a probability of 0.0288 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  39
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9726 winning the car
# If the user does not switch, s/he has a probability of 0.0255 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  40
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9745 winning the car
# If the user does not switch, s/he has a probability of 0.0259 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  41
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9751 winning the car
# If the user does not switch, s/he has a probability of 0.024 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  42
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9775 winning the car
# If the user does not switch, s/he has a probability of 0.0242 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  43
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9762 winning the car
# If the user does not switch, s/he has a probability of 0.0238 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  44
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9765 winning the car
# If the user does not switch, s/he has a probability of 0.0227 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  45
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.977 winning the car
# If the user does not switch, s/he has a probability of 0.0231 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  46
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9767 winning the car
# If the user does not switch, s/he has a probability of 0.0207 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  47
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9797 winning the car
# If the user does not switch, s/he has a probability of 0.0212 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  48
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9798 winning the car
# If the user does not switch, s/he has a probability of 0.0199 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  49
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9787 winning the car
# If the user does not switch, s/he has a probability of 0.0165 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  50
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9794 winning the car
# If the user does not switch, s/he has a probability of 0.0233 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  51
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.981 winning the car
# If the user does not switch, s/he has a probability of 0.0195 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  52
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9798 winning the car
# If the user does not switch, s/he has a probability of 0.02 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  53
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9819 winning the car
# If the user does not switch, s/he has a probability of 0.0177 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  54
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9813 winning the car
# If the user does not switch, s/he has a probability of 0.0159 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  55
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9793 winning the car
# If the user does not switch, s/he has a probability of 0.018 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  56
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.982 winning the car
# If the user does not switch, s/he has a probability of 0.0162 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  57
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9837 winning the car
# If the user does not switch, s/he has a probability of 0.0169 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  58
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9831 winning the car
# If the user does not switch, s/he has a probability of 0.0181 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  59
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9812 winning the car
# If the user does not switch, s/he has a probability of 0.0168 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  60
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9834 winning the car
# If the user does not switch, s/he has a probability of 0.0174 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  61
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9832 winning the car
# If the user does not switch, s/he has a probability of 0.0177 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  62
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9841 winning the car
# If the user does not switch, s/he has a probability of 0.0155 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  63
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9848 winning the car
# If the user does not switch, s/he has a probability of 0.0169 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  64
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9862 winning the car
# If the user does not switch, s/he has a probability of 0.0132 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  65
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9843 winning the car
# If the user does not switch, s/he has a probability of 0.0144 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  66
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9847 winning the car
# If the user does not switch, s/he has a probability of 0.0167 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  67
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9872 winning the car
# If the user does not switch, s/he has a probability of 0.0138 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  68
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9853 winning the car
# If the user does not switch, s/he has a probability of 0.0148 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  69
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9843 winning the car
# If the user does not switch, s/he has a probability of 0.0146 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  70
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9869 winning the car
# If the user does not switch, s/he has a probability of 0.0131 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  71
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9874 winning the car
# If the user does not switch, s/he has a probability of 0.0143 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  72
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9867 winning the car
# If the user does not switch, s/he has a probability of 0.0138 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  73
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9878 winning the car
# If the user does not switch, s/he has a probability of 0.0131 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  74
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9866 winning the car
# If the user does not switch, s/he has a probability of 0.0123 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  75
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9846 winning the car
# If the user does not switch, s/he has a probability of 0.0156 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  76
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9854 winning the car
# If the user does not switch, s/he has a probability of 0.0125 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  77
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.987 winning the car
# If the user does not switch, s/he has a probability of 0.0108 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  78
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9872 winning the car
# If the user does not switch, s/he has a probability of 0.013 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  79
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9881 winning the car
# If the user does not switch, s/he has a probability of 0.0121 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  80
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9891 winning the car
# If the user does not switch, s/he has a probability of 0.0155 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  81
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9887 winning the car
# If the user does not switch, s/he has a probability of 0.0121 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  82
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9879 winning the car
# If the user does not switch, s/he has a probability of 0.0138 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  83
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.988 winning the car
# If the user does not switch, s/he has a probability of 0.0132 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  84
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9882 winning the car
# If the user does not switch, s/he has a probability of 0.0124 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  85
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9884 winning the car
# If the user does not switch, s/he has a probability of 0.0145 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  86
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9871 winning the car
# If the user does not switch, s/he has a probability of 0.0102 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  87
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9873 winning the car
# If the user does not switch, s/he has a probability of 0.0114 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  88
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9892 winning the car
# If the user does not switch, s/he has a probability of 0.0116 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  89
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9891 winning the car
# If the user does not switch, s/he has a probability of 0.011 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  90
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9889 winning the car
# If the user does not switch, s/he has a probability of 0.0107 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  91
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9888 winning the car
# If the user does not switch, s/he has a probability of 0.0117 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  92
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9892 winning the car
# If the user does not switch, s/he has a probability of 0.0117 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  93
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.99 winning the car
# If the user does not switch, s/he has a probability of 0.0113 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  94
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9882 winning the car
# If the user does not switch, s/he has a probability of 0.0095 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  95
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9883 winning the car
# If the user does not switch, s/he has a probability of 0.011 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  96
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9878 winning the car
# If the user does not switch, s/he has a probability of 0.0103 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  97
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9896 winning the car
# If the user does not switch, s/he has a probability of 0.0105 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  98
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9898 winning the car
# If the user does not switch, s/he has a probability of 0.01 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  99
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9893 winning the car
# If the user does not switch, s/he has a probability of 0.0112 winning the car
# ****************************************************************************************************
# ****************************************************************************************************
# Number of doors:  100
# Number of trials:  10000
# If the user does switch, s/he has a probability of 0.9906 winning the car
# If the user does not switch, s/he has a probability of 0.0101 winning the car
# ****************************************************************************************************

# %% [markdown]
# As you can see with 3 doors, the probability of winning by switching is ~ 0.65, and it constantly increases, reaching to ~0.99 by 100 doors.
